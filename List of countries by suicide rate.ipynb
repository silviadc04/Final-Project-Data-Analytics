# %% [markdown]
# # List of countries by suicide rate (1990 - 2016)

# %%
import pandas as pd
import numpy as np

import seaborn as sns

# %%
df_raw=pd.read_csv("C:/Users/Lavoro/Desktop/Data/List of countries by suicide rate.csv")
df=df_raw.copy()
df.head()
# Out:
#         WHO region  Crude rate  Age-standardized rate  Crude male rate  \
# 0           Europe        15.4                  12.85             24.7
# 1   Southeast Asia        13.2                  13.40             14.8
# 2           Global        10.6                  10.53             13.5
# 3  Western Pacific        10.2                   8.45             10.9
# 4         Americas         9.8                   9.25             15.1
#
#    Crude female rate  Male–female ratio
# 0                6.6               3.74
# 1               11.6               1.28
# 2                7.7               1.75
# 3                9.4               1.16
# 4                4.6               3.28

# %%
df.at[6,'WHO region']='Eastern Mediterranean'

# %%
df
# Out:
#               WHO region  Crude rate  Age-standardized rate  Crude male rate  \
# 0                 Europe        15.4                  12.85             24.7
# 1         Southeast Asia        13.2                  13.40             14.8
# 2                 Global        10.6                  10.53             13.5
# 3        Western Pacific        10.2                   8.45             10.9
# 4               Americas         9.8                   9.25             15.1
# 5                 Africa         7.4                  11.96              9.9
# 6  Eastern Mediterranean         3.9                   4.30              5.1
#
#    Crude female rate  Male–female ratio
# 0                6.6               3.74
# 1               11.6               1.28
# 2                7.7               1.75
# 3                9.4               1.16
# 4                4.6               3.28
# 5                4.8               2.06
# 6                2.7               1.89
